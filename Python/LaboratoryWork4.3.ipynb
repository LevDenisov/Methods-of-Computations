# %% [markdown]
# ## Сделал Денисов Лев с Дмитрием Калининым
#
# ### Какую математическую задачу позволяет решить Ваша программа?
#
# - Приближённое вычисление интеграла по составным квадратурным формулам
#
# ### Какой/какие численные методы Вы используете для нахождения решения упомянутой математической задачи?
#
# - CКФ левого прямоугольника
# - CКФ правого прямоугольника
# - CКФ среднего прямоугольника
# - CКФ трапеции
# - CКФ Симпсона
#
# ### Каковы исходные параметры задачи? Какие параметры в вашей программе можно менять? Как осуществляется ввод параметров? (из файла, с клавиатуры, присвоением соответствующих значений в коде программы и т.п.)
#
# - Границы  интегрирования  (из  ĸонсоли),  интегрируемая  фунĸция, количество разбиений
#
# ### На каком языке программирования (с использованием какой интерактивной среды и т.п.) написана Ваша программа? Какие типы переменных Вы используете в расче- тах?
#
# - Python  в  Jupyter  Notebook,  math.  Типы  переменных:  int,  float

# %% [markdown]
# ## Импорт необходимых библиотек

# %%
import math

# %% [markdown]
# ## Алгоритмы приближенного вычисления интеграла по квадратурным формулам

# %% [markdown]
# #### CКФ левого прямоугольника

# %%
def complex_left_rectangle_method(f, a, b, m):
    h = (b - a) / m
    return h * sum(f(a + i * h) for i in range(0, m))

# %% [markdown]
# #### CКФ правого прямоугольника

# %%
def complex_right_rectangle_method(f, a, b, m):
    h = (b - a) / m
    return h * sum(f(a + i * h) for i in range(1, m + 1))

# %% [markdown]
# #### CКФ среднего прямоугольника

# %%
def complex_middle_rectangle_method(f, a, b, m):
    h = (b - a) / m
    return h * sum(f(a + i * h + h / 2) for i in range(0, m))

# %% [markdown]
# #### СКФ трапеций

# %%
def complex_trapeze_method(f, a, b, m):
    return (complex_left_rectangle_method(f, a, b, m) + complex_right_rectangle_method(f, a, b, m)) / 2

# %% [markdown]
# #### СКФ Симпсона

# %%
def complex_simpson_method(f, a, b, m):
    return (complex_left_rectangle_method(f, a, b, m) + complex_right_rectangle_method(f, a, b, m) +
            4 * complex_middle_rectangle_method(f, a, b, m)) / 6

# %% [markdown]
# ## Произвольные функции

# %% [markdown]
# #### Произвольная функция №1

# %%
def f_custom(x):
    return math.cos(x) - 2 * x


def der_f_custom(x):
    return (-1) * math.sin(x) - 2


def integral_f_custom(a, b):
    return math.sin(b) - math.sin(a) + a * a - b * b

# %% [markdown]
# #### Произвольная функция №2

# %%
def f_0(x):
    return 1


def der_f_0(x):
    return 0


def integral_f_0(a, b):
    return b - a

# %% [markdown]
# #### Произвольная функция №3

# %%
def f_1(x):
    return 2 * x


def der_f_1(x):
    return 2


def integral_f_1(a, b):
    return b * b - a * a

# %% [markdown]
# #### Произвольная функция №4

# %%
def f_2(x):
    return 3 * (x ** 2)


def der_f_2(x):
    return 6 * x


def integral_f_2(a, b):
    return b ** 3 - a ** 3

# %% [markdown]
# #### Произвольная функция №5

# %%
def f_3(x):
    return 4 * (x ** 3)


def der_f_3(x):
    return 12 * (x ** 2)


def der_2_f_3(x):
    return 24 * x


def der_3_f_3(x):
    return 24


def der_4_f_3(x):
    return 0


def integral_f_3(a, b):
    return b ** 4 - a ** 4

# %% [markdown]
# ## Задание параметров

# %%
print("Приближённое вычисление интеграла по составным квадратурным формулам")
a, b = float(input("Введите границу интегрирования a: ")), float(input("Введите границу интегрирования b: "))
m = int(input("Введите параметр m: "))
l = int(input("Введите параметр l: "))
funcs = {f_custom: integral_f_custom, f_0: integral_f_0, f_1: integral_f_1, f_2: integral_f_2, f_3: integral_f_3}
ders = {0: der_f_3, 1: der_2_f_3, 3: der_4_f_3}
funcs_str = {f_custom: "cos(x) - 2 * x", f_0: "1", f_1: "2 * x", f_2: "3 * (x ** 2)", f_3: "4 * (x ** 3)"}
# Out:
# Приближённое вычисление интеграла по составным квадратурным формулам
# Введите границу интегрирования a: 0
# Введите границу интегрирования b: 1
# Введите параметр m: 5
# Введите параметр l: 5

# %% [markdown]
# ## Приближенное вычисление интегралов

# %%
for f in funcs.keys():
    print("\n", f"Функция f: {funcs_str[f]}")
    j = funcs[f](a, b)
    methods = {"СКФ левых прямоугольников": complex_left_rectangle_method,
               "СКФ правых прямоугольников": complex_right_rectangle_method,
               "СКФ средних прямоугольников": complex_middle_rectangle_method,
               "СКФ трапеций": complex_trapeze_method, "СКФ Симпсона": complex_simpson_method}
    ast = {complex_left_rectangle_method: 0,
              complex_right_rectangle_method: 0,
              complex_middle_rectangle_method: 1,
              complex_trapeze_method: 1, complex_simpson_method: 3}
    for i in methods.keys():
        h = (b - a) / m
        print("======================================")
        print(i)
        j_h = methods[i](f, a, b, m)
        j_h_l = methods[i](f, a, b, m * l)
        print("Значение интеграла по данной формуле для m*l делений:", j_h_l)
        print("Абсолютная фактическая погрешность для m*l делений:", abs(j_h_l - j))
        ast_cur = ast[methods[i]]
        _j = ((l ** (ast_cur + 1)) * j_h_l - j_h) / (l ** (ast_cur + 1) - 1)
        print("Уточненное значение по принципу Рунге:", _j)
        print("Абсолютная фактическая погрешность для уточненного значения:", abs(_j - j))
# Out:
#  Функция f: cos(x) - 2 * x
# ======================================
# СКФ левых прямоугольников
# Значение интеграла по данной формуле для m*l делений: -0.10944726043278481
# Абсолютная фактическая погрешность для m*l делений: 0.04908175475931868
# Уточненное значение по принципу Рунге: -0.1579675703460295
# Абсолютная фактическая погрешность для уточненного значения: 0.0005614448460739829
# ======================================
# СКФ правых прямоугольников
# Значение интеграла по данной формуле для m*l делений: -0.20783516819805922
# Абсолютная фактическая погрешность для m*l делений: 0.04930615300595573
# Уточненное значение по принципу Рунге: -0.15796757034602948
# Абсолютная фактическая погрешность для уточненного значения: 0.0005614448460740107
# ======================================
# СКФ средних прямоугольников
# Значение интеграла по данной формуле для m*l делений: -0.15847291450842957
# Абсолютная фактическая погрешность для m*l делений: 5.61006836739264e-05
# Уточненное значение по принципу Рунге: -0.15852908071169045
# Абсолютная фактическая погрешность для уточненного значения: 6.551958695033555e-08
# ======================================
# СКФ трапеций
# Значение интеграла по данной формуле для m*l делений: -0.15864121431542202
# Абсолютная фактическая погрешность для m*l делений: 0.00011219912331852933
# Уточненное значение по принципу Рунге: -0.15852894032052325
# Абсолютная фактическая погрешность для уточненного значения: 7.487158024122031e-08
# ======================================
# СКФ Симпсона
# Значение интеграла по данной формуле для m*l делений: -0.15852901444409373
# Абсолютная фактическая погрешность для m*l делений: 7.480097652390327e-10
# Уточненное значение по принципу Рунге: -0.1585290151929607
# Абсолютная фактическая погрешность для уточненного значения: 8.572031973130834e-13
#
#  Функция f: 1
# ======================================
# СКФ левых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ правых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ средних прямоугольников
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ трапеций
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ Симпсона
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
#
#  Функция f: 2 * x
# ======================================
# СКФ левых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 0.96
# Абсолютная фактическая погрешность для m*l делений: 0.040000000000000036
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ правых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 1.04
# Абсолютная фактическая погрешность для m*l делений: 0.040000000000000036
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ средних прямоугольников
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ трапеций
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ Симпсона
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
#
#  Функция f: 3 * (x ** 2)
# ======================================
# СКФ левых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 0.9408000000000002
# Абсолютная фактическая погрешность для m*l делений: 0.05919999999999981
# Уточненное значение по принципу Рунге: 0.9960000000000001
# Абсолютная фактическая погрешность для уточненного значения: 0.0039999999999998925
# ======================================
# СКФ правых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 1.0608000000000002
# Абсолютная фактическая погрешность для m*l делений: 0.06080000000000019
# Уточненное значение по принципу Рунге: 0.9960000000000002
# Абсолютная фактическая погрешность для уточненного значения: 0.0039999999999997815
# ======================================
# СКФ средних прямоугольников
# Значение интеграла по данной формуле для m*l делений: 0.9995999999999999
# Абсолютная фактическая погрешность для m*l делений: 0.00040000000000006697
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
# ======================================
# СКФ трапеций
# Значение интеграла по данной формуле для m*l делений: 1.0008000000000001
# Абсолютная фактическая погрешность для m*l делений: 0.0008000000000001339
# Уточненное значение по принципу Рунге: 1.0000000000000002
# Абсолютная фактическая погрешность для уточненного значения: 2.220446049250313e-16
# ======================================
# СКФ Симпсона
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
#
#  Функция f: 4 * (x ** 3)
# ======================================
# СКФ левых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 0.9216
# Абсолютная фактическая погрешность для m*l делений: 0.07840000000000003
# Уточненное значение по принципу Рунге: 0.9919999999999999
# Абсолютная фактическая погрешность для уточненного значения: 0.008000000000000118
# ======================================
# СКФ правых прямоугольников
# Значение интеграла по данной формуле для m*l делений: 1.0816
# Абсолютная фактическая погрешность для m*l делений: 0.0815999999999999
# Уточненное значение по принципу Рунге: 0.9919999999999998
# Абсолютная фактическая погрешность для уточненного значения: 0.00800000000000023
# ======================================
# СКФ средних прямоугольников
# Значение интеграла по данной формуле для m*l делений: 0.9992000000000001
# Абсолютная фактическая погрешность для m*l делений: 0.0007999999999999119
# Уточненное значение по принципу Рунге: 1.0000000000000002
# Абсолютная фактическая погрешность для уточненного значения: 2.220446049250313e-16
# ======================================
# СКФ трапеций
# Значение интеграла по данной формуле для m*l делений: 1.0015999999999998
# Абсолютная фактическая погрешность для m*l делений: 0.0015999999999998238
# Уточненное значение по принципу Рунге: 0.9999999999999999
# Абсолютная фактическая погрешность для уточненного значения: 1.1102230246251565e-16
# ======================================
# СКФ Симпсона
# Значение интеграла по данной формуле для m*l делений: 1.0
# Абсолютная фактическая погрешность для m*l делений: 0.0
# Уточненное значение по принципу Рунге: 1.0
# Абсолютная фактическая погрешность для уточненного значения: 0.0
